# %% [markdown]
# <a href="https://colab.research.google.com/github/RickeyEstes2/Public/blob/main/Time%20Independent%20Schrodinger%20Equation%20In%20One%20Dimension%201.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###<center><b>By Rickey Estes</b></center>
#
# ## <b>The Time Independent Schrödinger Equation in 1 Dimension: </b><br>
# - Removing y, z and t leaves us with the 1 dimensional, time independent Schrodinger equation.<br><br>
#
# #$$i \hbar \frac{\partial}{\partial t}\Psi(\mathbf{r},t) = \hat H \Psi(\mathbf{r},t)$$

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
h = 1
m = 1

# %%
a=1
V=0

# %%
psi=0
dpsi=1
x=0
dx=a*0.001

xlist=[]
psilist=[]

E=123.12
#E=1
while x<=a:
  #second derivative of psi
  ddpsi=2*m/h**2*(V-E)*psi

  #first derivative of psi
  dpsi=dpsi+ddpsi*dx

  psi=psi+dpsi*dx
  x=x+dx
  xlist.append(x)
  psilist.append(psi)
  plt.plot(xlist,psilist)

# %%
E=0
dE=0.01
dx=a*0.001
psi=1

while abs(psi)>0.001:
  psi=0
  dpsi=1
  x=0
  E=E+dE
  xlist=[]
  psilist=[]

  while x<=a:
    ddpsi=2*m/h**2*(V-E)*psi
    dpsi=dpsi+ddpsi*dx
